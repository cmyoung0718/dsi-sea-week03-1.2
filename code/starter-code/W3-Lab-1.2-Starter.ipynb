# %% [markdown]
# # Plotting the Housing Data
#
# A good first step when working with any new data set is to do some exploratory data analysis, starting with a plots of the data. Let's download the data. There is some information about the [data set](https://archive.ics.uci.edu/ml/datasets/Housing) at the UCI ML repository. It's a good idea to take a look at the dataset description before proceeding.

# %%
# %matplotlib inline

# Download the data, save to a file called "housing.data"
import urllib
data_url = "https://archive.ics.uci.edu/ml/machine-learning-databases/housing/housing.data"
urllib.urlretrieve (data_url, "housing.data")
# Out:
# ('housing.data', <httplib.HTTPMessage instance at 0x18c1de3b0>)

# %% [markdown]
# The data file does not contain the column names in the first line, so we'll need to add those in manually. You can find the names and explanations [here](https://archive.ics.uci.edu/ml/machine-learning-databases/housing/housing.names). We've extracted the names below for convenience.

# %%
names = ["CRIM", "ZN", "INDUS", "CHAS", "NOX", "RM", "AGE",
         "DIS", "RAD", "TAX", "PTRATIO", "B", "LSTAT", "MEDV"]

# %% [markdown]
# ## Loading the Data
#
# Now let's use pandas to load the data into a data frame. Note that the data is space separated (rather than the more common comma separated data). Here are the first few lines:
#
# ```
# 0.00632  18.00   2.310  0  0.5380  6.5750  65.20  4.0900   1  296.0  15.30 396.90   4.98  24.00
# 0.02731   0.00   7.070  0  0.4690  6.4210  78.90  4.9671   2  242.0  17.80 396.90   9.14  21.60
# ```

# %%
import pandas as pd

data = pd.read_csv("housing.data", header=None, names=names, delim_whitespace=True)

# Take a look at the first few rows
data.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %% [markdown]
# ### Knowledge Check:
#
# How many rows are in the dataset?

# %%
# Compute the number of rows
print 'There are',data.shape[0], 'rows in the dataset.'
# Out:
# There are 506 rows in the dataset.

# %% [markdown]
# ## Plotting the Data
#
# We are interested in the house values, given in column "MEDV" as a target for modeling. By plotting each of the other columns against "MEDV" we can get a sense of which variables may be correlated.
#
# There are many ways we can plot the data, using `pandas`, `matplotlib`, or `seaborn`. In any case, it's nice to import `seaborn` for the improved styling. Let's try using `pandas` first to make a scatter plot of crime (column "CRIM") versus house value ("MEDV").

# %%
import seaborn as sns

# Plot using pandas
data.plot(x='CRIM', y='MEDV', kind ='scatter')

# %% [markdown]
# It looks like there is a relationship. While houses in low crime areas can have a wide range of values, houses in high crime areas appear to have lower values.
#
# Knowledge checks:
# * How do we select a column of data from a pandas DataFrame?
# * Let's make the same plot with matplotlib.

# %%
# Knowledge Check Solution
print 'By using the syntax dataframe["column_name"]'
from matplotlib import pyplot as plt

# Plot using matplotlib
plt.scatter(data["CRIM"], data["MEDV"])
plt.xlabel("Crime")
plt.ylabel("House Value")
# Out:
# By using the syntax dataframe["column_name"]

# %% [markdown]
# ### Exercises
#
# Exercise 1: Using `pandas` or `matplotlib` plot the remaining variables against "MEDV" and discuss the relationships you find. Question: Which variables seem to correlate well?
#
# ### Bonus Exercises
#
# Exercise 2: Seaborn is very handy for making plots of data for exploratory purposes. Try using `seaborn`'s [pairplots](https://stanford.edu/~mwaskom/software/seaborn/examples/scatterplot_matrix.html) to make similar plots.
#
# Exercise 3: Improve your plots by including units and better axis labels. You'll need to read the [data set description](https://archive.ics.uci.edu/ml/machine-learning-databases/housing/housing.names).
#
# Exercise 4: Can you find any visual correlations between two variables other than MEDV?

# %%
# Exercise 1: Using pandas or matplotlib plot the remaining variables against "MEDV" and discuss the relationships 
# you find. Question: Which variables seem to correlate well?

# Looking at the graphs below, there seems to be a positive relationship between House Value and the 
# average number of rooms per dwelling.  This means that as the house value goes up, the number of rooms per house
# also tends to go up.
# There is also a positive relationship between House Value and the weighted distances to five Boston employment
# centres.  This means that as the house value goes up, the distance to employment centers tends to go up as well.
 

# There seems to be a negative relationship between House Value and proportion of non-retail business acres per
# town, nitric oxides concentration, proportion of owner-occupied units built prior to 1940, full-value property-tax 
# rate per $10,000, and pupil-teacher ratio by town.  This means that as house value goes up, the proportion of non-retail
# business acres, nitric oxide concentration, proportion of owner-occupied units built prior to 1940, full-value
# property tax rate per $10,000, and pupil-teacher ratio all go down.

for i in data:
    if i != 'CRIM':
        plt.scatter(data[i], data["MEDV"])
        plt.xlabel(i)
        plt.ylabel("House Value")
        plt.show()

# %%
# Exercise 2
sns.pairplot(data=data, kind='reg')

# %%
# Exercise 3: Improve your plots by including units and better axis labels.
data_rename = data
data_rename.columns = ["Crime (Per Capita)", "Residential Zoning (Proportion)", "Non-Retail Businesses (acres per town)", 
                       "Charles River Distance (= 1 if tract bounds river; 0 otherwise)" , "NOX Concentration (parts per 10 million)"
                       , "Rooms per House", "Houses Built before 1940 (proportion)", "Distance to Employment Centers",
                       "Accessibility to Highways", "Tax Value (per $10,000)", "Pupil:Teacher Ratio", "Afr. Amer. Proportion", 
                       "Lower Status of the Population (%)", "Median Value (in $1,000s)"]
for i in data_rename:
        plt.scatter(data_rename[i], data_rename["Median Value (in $1,000s)"])
        plt.xlabel(i)
        plt.ylabel("Median Value (in $1,000s)")
        plt.show()

# %%
# Exercise 4: Can you find any visual correlations between two variables other than MEDV?

# Looking at the pairplot I created using Seaborn, I can see quite a few other correlations.
# A couple of the positive correlations are LSTAT and INDUS and Age and NOX. 
# Some of the negative correlations are RM and LSTAT, Age and DIS, NOX and ZN, and NOX and DIS.
